# %% [markdown]
# Pretrained Tokenizer

# %%
from transformers import AutoTokenizer

# %%
model = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model)

# %%
sentence = "I am very much Excited"
input_id = tokenizer(sentence)

# %%
input_id
# Out:
# {'input_ids': [101, 1045, 2572, 2200, 2172, 7568, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1]}

# %%
tokens = tokenizer.tokenize(sentence)
tokens
# Out:
# ['i', 'am', 'very', 'much', 'excited']

# %%
tokens_id = tokenizer.convert_tokens_to_ids(tokens)
tokens_id
# Out:
# [1045, 2572, 2200, 2172, 7568]

# %%
decoded_id = tokenizer.decode(tokens_id)
decoded_id
# Out:
# 'i am very much excited'

# %%
tokenizer.decode([101])
# Out:
# '[CLS]'

# %%
tokenizer.decode([102])
# Out:
# '[SEP]'

# %%
model2 = "xlnet-base-cased"
tokenizer2 = AutoTokenizer.from_pretrained(model2)

# %%
input_id2 = tokenizer2(sentence)
input_id2
# Out:
# {'input_ids': [35, 569, 172, 178, 18094, 669, 68, 4, 3], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0, 2], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1, 1]}

# %%
tokens2 = tokenizer2.tokenize(sentence)
tokens2
# Out:
# ['▁I', '▁am', '▁very', '▁much', '▁Exc', 'it', 'ed']

# %%
tokens_id2 = tokenizer2.convert_tokens_to_ids(tokens2)
tokens_id2
# Out:
# [35, 569, 172, 178, 18094, 669, 68]

# %%
tokenizer2.decode(4)
# Out:
# '<sep>'

# %%
tokenizer2.decode(3)
# Out:
# '<cls>'
